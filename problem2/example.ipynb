# %%
import torch
import torchvision
#for graph visualization
import random
from matplotlib import pyplot as plt
from torch_geometric.utils import to_networkx
import networkx as nx
from dgl.data import *
from torch_geometric.datasets import Planetoid
from utils import *
# %load_ext autoreload 
# %autoreload 2

# %%
dataset = Planetoid(root = '/tmp/cora', name = 'CORA')
graph = dataset[0]
G = to_networkx(graph,to_undirected=True)

# %%
plot_graph(graph)

# %%
plot_graph(graph)

# %%
central_and_cluster(G)
# Out:
# array([[9.76615355e-07, 1.10823790e-03, 9.05766833e-05, ...,
#         3.33333333e-01, 0.00000000e+00, 9.09090909e-02],
#        [1.08047671e-03, 1.10823790e-03, 9.46457653e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.05081627e-03, 1.84706317e-03, 1.34609896e-03, ...,
#         0.00000000e+00, 0.00000000e+00, 3.34448161e-03],
#        ...,
#        [0.00000000e+00, 3.69412634e-04, 7.40293027e-33, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.96352841e-05, 1.47765054e-03, 5.62591416e-05, ...,
#         5.00000000e-01, 0.00000000e+00, 3.33333333e-01],
#        [1.67759753e-04, 1.47765054e-03, 2.37370599e-04, ...,
#         8.33333333e-01, 0.00000000e+00, 7.61904762e-02]])

# %%
importance_plot(G,graph,layout='spectral_layout',part=None
               ,k=0.3 ,method='degree',best=0.25,good=0.1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 importance_plot(G,graph,layout='spectral_layout',part=None
#       2                ,k=0.3 ,method='degree',best=0.25,good=0.1)
#
# File ~\d2l-zh\asset pricing and portfolio optimization\social network\Task2\utils.py:64, in importance_plot(G, graph, layout, part, method, k, best, good)
#      62     pos = nx.spring_layout(G,k=k,seed=100)
#      63 elif layout=='spectral_layout':
# ---> 64     pos = nx.spectral_layout(G,seed=100)
#      65 elif layout=='random_layout':
#      66     pos = nx.random_layout(G,seed=100)
#
# TypeError: spectral_layout() got an unexpected keyword argument 'seed'

# %%
importance_plot(G,graph,part=4
                ,method='voterank',number=40)

# %%
importance_plot(G,graph,part=4
               ,k=0.3 ,method='voterank',best=0.25,good=0.1)

# %%
importance_plot(G,graph,part=None
               ,k=0.3 ,method='katz',best=0.25,good=0.1)
# Out:
# C:\APPs\anaconda\envs\d2l\lib\site-packages\matplotlib\cbook\__init__.py:1026: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.asanyarray(x)
# True

# %%
importance_plot(G,graph,part=None
               ,k=0.3 ,method='eigen',best=0.25,good=0.1)
# Out:
# True

# %%
importance_plot(G,graph,part=None
               ,k=0.3 ,method='degree',best=0.25,good=0.1)
# Out:
# True

# %%
importance_plot(G, part=None,method='katz')
# Out:
# True

# %%
if nx.is_connected(G):
    # Average distance
    ave_len = nx.average_shortest_path_length(G)
    print("Average distance:", ave_len)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 ave_len = nx.average_shortest_path_length(G)
#       2 print("Average distance:", ave_len)
#
# File C:\APPs\anaconda\envs\d2l\lib\site-packages\networkx\algorithms\shortest_paths\generic.py:412, in average_shortest_path_length(G, weight, method)
#     410 # Shortest path length is undefined if the graph is not connected.
#     411 if not G.is_directed() and not nx.is_connected(G):
# --> 412     raise nx.NetworkXError("Graph is not connected.")
#     414 # Compute all-pairs shortest paths.
#     415 def path_length(v):
#
# NetworkXError: Graph is not connected.

# %%
components = nx.connected_components(G) 
for i in components:
    Diameter = nx.diameter(i)
    print("Diameter:", Diameter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[218], line 3
#       1 components = nx.connected_components(G)
#       2 for i in components:
# ----> 3     Diameter = nx.diameter(i)
#       4     print("Diameter:", Diameter)
#
# File C:\APPs\anaconda\envs\d2l\lib\site-packages\networkx\algorithms\distance_measures.py:377, in diameter(G, e, usebounds, weight)
#     375     return _extrema_bounding(G, compute="diameter", weight=weight)
#     376 if e is None:
# --> 377     e = eccentricity(G, weight=weight)
#     378 return max(e.values())
#
# File C:\APPs\anaconda\envs\d2l\lib\site-packages\networkx\algorithms\distance_measures.py:296, in eccentricity(G, v, sp, weight)
#     239 """Returns the eccentricity of nodes in G.
#     240
#     241 The eccentricity of a node v is the maximum distance from v to
#    (...)
#     288
#     289 """
#     290 #    if v is None:                # none, use entire graph
#     291 #        nodes=G.nodes()
#     292 #    elif v in G:               # is v a single node
#     293 #        nodes=[v]
#     294 #    else:                      # assume v is a container of nodes
#     295 #        nodes=v
# --> 296 order = G.order()
#     297 e = {}
#     298 for n in G.nbunch_iter(v):
#
# AttributeError: 'set' object has no attribute 'order'

# %%
# Out:
# Clustering: 0.24067329850193728

# %%
import math

# Degree
# 存储度数相应点数
number = []
# 存储度数
degree = []
for i in nx.degree_histogram(G):
    number.append(i)
for j in range(len(nx.degree_histogram(G))):
    degree.append(j)
# 去掉number=0,并取log
logxy = {}
for i in range(len(degree)):
    if (number[i] != 0):
        logxy[math.log(degree[i])] = math.log(number[i])

# 作图
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title('Cora Dataset')
plt.xlabel("log(degree)")
plt.ylabel("log(number)")
plt.scatter(logxy.keys(), logxy.values(), c="red", s=10)

# %%
y = graph.y.numpy()

# %%
y
# Out:
# array([3, 4, 4, ..., 3, 3, 3], dtype=int64)

# %%
color = []
a=nx.voterank(G,50)
for i in a:
    color.append("r")
    
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.set_title("part:pagerank centrality")
    nx.draw_networkx_nodes(G, pos, node_size=15, node_color=color)
    nx.draw_networkx_edges(G, pos, alpha=0.5)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[192], line 3
#       1 a=nx.voterank(G,50)
#       2 for i in a:
# ----> 3     color.append("r")
#       5     fig = plt.figure()
#       6     ax1 = fig.add_subplot(111)
#
# NameError: name 'color' is not defined

# %%
max_center_value = max(a.values())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 max_center_value = max(a.values())
#
# AttributeError: 'list' object has no attribute 'values'

# %%
degree_dict = nx.degree_centrality(G)

# %%
pos = nx.spring_layout(G,k=0.15,seed=100)
color = []
a=nx.voterank(G,1)
for i in degree_dict.keys():
    if i in a:
        color.append("r")
    else:
        color.append([0.5, 0.5, 0.5])
    
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("part:pagerank centrality")
nx.draw_networkx_nodes(G, pos, node_size=15, node_color=color)
nx.draw_networkx_edges(G, pos, alpha=0.5)
plt.show()

# %%
n = 1000
pos = nx.spring_layout(G)

for c in [0.01, 0.1, 1, 10]:

    subG = G.subgraph(max(nx.connected_components(G),key=len))
    
    print("==========================")
    # Average degree
    ave_deg = len(G.edges())*2/n
    print("Average degree:", ave_deg)

    Clus = nx.average_clustering(subG)
    print("Clustering:", Clus)

    # Average distance
    ave_len = nx.average_shortest_path_length(subG)
    print("Average distance:", ave_len)

    # Diameter
    Diameter = nx.diameter(subG)
    print("Diameter:", Diameter)

    # Size
    size = len(subG.nodes())
    print("Size:", size)


    nx.draw_networkx_nodes(G, pos, node_size=15)
    nx.draw_networkx_edges(G, pos, alpha=0.5)
    plt.show()
# Out:
# ==========================
# Average degree: 10.556
# Clustering: 0.23763551095541188
# Average distance: 6.310998681298742
# Diameter: 19
# Size: 2485
# ==========================
# Average degree: 10.556
# Clustering: 0.23763551095541188
# Average distance: 6.310998681298742
# Diameter: 19
# Size: 2485
# ==========================
# Average degree: 10.556
# Clustering: 0.23763551095541188
# Average distance: 6.310998681298742
# Diameter: 19
# Size: 2485
# ==========================
# Average degree: 10.556
# Clustering: 0.23763551095541188
# Average distance: 6.310998681298742
# Diameter: 19
# Size: 2485

# %%
    G1 = G.copy()
    G1.remove_nodes_from(nx.isolates(G1))
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.set_title("part2:after removing isolates")
    nx.draw_networkx_nodes(G1, pos, node_size=15, node_color=[0.5, 0.5, 0.5])
    nx.draw_networkx_edges(G1, pos, alpha=0.5)
    plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
    G2 = G1.copy()
    G2.remove_nodes_from(list(nx.articulation_points(G2)))
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.set_title("part3:after removing articulation points")
    nx.draw_networkx_nodes(G2, pos, node_size=15, node_color=[0.5, 0.5, 0.5])
    nx.draw_networkx_edges(G2, pos, alpha=0.5)
    plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
    G3 = G2.copy()
    G3.remove_nodes_from(list(nx.k_core(G3, k=2)))
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.set_title("part4:after removing k-core")
    nx.draw_networkx_nodes(G3, pos, node_size=15, node_color=[0.5, 0.5, 0.5])
    nx.draw_networkx_edges(G3, pos, alpha=0.5)
    plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
    G4 = G3.copy()
    G4.remove_nodes_from(list(nx.k_core(G4, k=3)))
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.set_title("part5:after removing k-core")
    nx.draw_networkx_nodes(G4, pos, node_size=15, node_color=[0.5, 0.5, 0.5])
    nx.draw_networkx_edges(G4, pos, alpha=0.5)
    plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
    G5 = G4.copy()
    G5.remove_nodes_from(list(nx.k_core(G5, k=1)))
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.set_title("part6:after removing k-core")
    nx.draw_networkx_nodes(G5, pos, node_size=15, node_color=[0.5, 0.5, 0.5])
    nx.draw_networkx_edges(G5, pos, alpha=0.5)
    plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# %load_ext autoreload 
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
draw_evolution(G,graph, layout='spring_layout', k=0.15)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 draw_evolution(G,graph, layout='spring_layout', k=0.15)
#
# File c:\Users\Zhou\d2l-zh\asset pricing and portfolio optimization\social network\Task2\Social-Network-Project\problem2\utils.py:272, in draw_evolution(G, graph, layout, part, k)
#     270 # 画出第二次演化图
#     271 G2 = G.copy()
# --> 272 G2.remove_edges_from(list(nx.articulation_points(G2)))
#     273 fig = plt.figure()
#     274 ax1 = fig.add_subplot(111)
#
# File c:\APPs\anaconda\envs\d2l\lib\site-packages\networkx\classes\graph.py:1152, in Graph.remove_edges_from(self, ebunch)
#    1150 adj = self._adj
#    1151 for e in ebunch:
# -> 1152     u, v = e[:2]  # ignore edge data if present
#    1153     if u in adj and v in adj[u]:
#    1154         del adj[u][v]
#
# TypeError: 'int' object is not subscriptable

# %%
draw_evolution(G,graph, layout='spring_layout',part=6, k=0.15)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
central_and_cluster(G).shape
# Out:
# (2708, 8)

# %%
draw_graph()
# Out:
# 规则图的节点间平均距离为： 2.912937299708235
# 规则图的平均群聚系数为： 0.006938505791805895
# 规则图的直径为： 4
# 规则图的diameter为： 4
# ER随机图的节点间平均距离为： 2.7551293517162954
# ER随机图的平均群聚系数为： 0.009725152504324609
# ER随机图的直径为： 4
# ER随机图的diameter为： 4
# BA无标度网络的节点间平均距离为： 2.7875566328120267
# BA无标度网络的平均群聚系数为： 0.028754563435912886
# BA无标度网络的直径为： 4
# BA无标度网络的diameter为： 4
# WS小世界网络的节点间平均距离为： 5.233245063539519
# WS小世界网络的平均群聚系数为： 0.49932121669566265
# WS小世界网络的直径为： 8
# WS小世界网络的diameter为： 8
# 星形网络的节点间平均距离为： 1.999261447562777
# 星形网络的平均群聚系数为： 0.0
# 星形网络的直径为： 2
# 星形网络的diameter为： 2
# 环形网络的节点间平均距离为： 677.2500923531585
# 环形网络的平均群聚系数为： 0.0
# 环形网络的直径为： 1354
# 环形网络的diameter为： 1354

# %%
K_score(G,graph,part=4,K=0,with_labels=True)

# %%
#构建规则图
G1 = nx.random_graphs.random_regular_graph(20, 2708)
#构建ER随机图
G2 = nx.erdos_renyi_graph(2708, 0.01)
#构建BA无标度网络
G3 = nx.barabasi_albert_graph(2708, 10)
#构建WS小世界网络
G4 = nx.watts_strogatz_graph(2708, 10, 0.1)
#构建星形网络
G5 = nx.star_graph(2707)
#构建环形网络
G6 = nx.cycle_graph(2708)

# %%
degree_plot(G6,title='cycle_graph')
